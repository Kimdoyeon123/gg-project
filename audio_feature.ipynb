# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import json
import os
import numpy as np
import openpyxl

# %% [markdown]
# # 엑셀 파일로 노래라벨링된거에서 audio feature 추출할때

# %%
import pandas as pd

# anger, disgust, fear, joy, neutral, sadness, surprise
# 엑셀 파일 경로 설정 (경로를 절대 경로로 정확하게 설정해야 합니다)
excel_file_path = 'C:/Users/LG/Desktop/VScode/gg-project/excel_file/anger.xlsx'  
# 실제 엑셀 파일 이름으로 대체

# 엑셀 파일 읽기
df = pd.read_excel(excel_file_path)

# 'ID' 열에서 track_id 가져오기
track_ids = df['id'].tolist()

# track_ids 확인
print(track_ids)
# Out:
# ['15JINEqzVMv3SvJTAXAKED', '42GcjriRK6srwHkfbkBqVl', '259wZqRoiqkrRMosDDnnOX', '1jCRPdDQvCA5kQXtrPFWPC', '44qSm80CrnBt3Mry9vYE41', '1mXuMM6zjPgjL4asbBsgnt', '6F5c58TMEs1byxUstkzVeM', '7fBv7CLKzipRk6EC6TWHOB', '0pqnGHJpmpxLKifKRmU6WP', '6C734SmqoIYuRWo2qSCnpC', '4f3E2bdBCYDvC0otoYcdXg', '2igwFfvr1OAGX9SKDCPBwO', '2SVhXAyqWACGVzVv8jWeRf', '6tNQ70jh4OwmPGpYy6R2o9', '1nInOsHbtotAmEOQhtvnzP', '0tokbEw27FxVHubsv8ZYN4', '4VrWlk8IQxevMvERoX08iC', '1Yk0cQdMLx5RzzFTYwmuld', '4fOfwLHQJz49Q8T1jrz54I', '3I71PFicYG614VGl6hqcUK', '0JtYYcQ330UyNftbi1tM0H', '7mCdQsRW5gLLxVGDPPGt5j', '1uMLtqpe8beA6fPy3ApJcJ', '1uMLtqpe8beA6fPy3ApJcJ', '63jOB9nkgSTrmwTvmfO3DE', '70LcF31zb1H0PyJoS1Sx1r', '3dYD57lRAUcMHufyqn9GcI', '2gMXnyrvIjhVBUZwvLZDMP', '4RVwu0g32PAqgUiJoXsdF8', '6UjZ2Yx2g2a52XxiA8ONxZ', '6GyFP1nfCDB8lbD2bG0Hq9', '6fNhZRFEkBfgW39W3wKARJ', '5VC29kHMkzcaorzPKUqJbl', '3DK6m7It6Pw857FcQftMds', '1s9i7W8zx7Nxx78MUIsvjV', '59wlTaYOL5tDUgXnbBQ3my', '6ZFbXIJkuI1dVNWvzJzown', '6gDXbcILAyBa2skSdbUYq7', '6kwAbEjseqBob48jCus7Sz', '3XF5xLJHOQQRbWya6hBp7d', '60a0Rd6pjrkxjPbaKzXjfq', '7MXlTgQeo3IVlMpLnZuhxc', '62yJjFtgkhUrXktIoSjgP2', '4CeeEOM32jQcH3eN9Q2dGj', '60wwxj6Dd9NJlirf84wr2c', '5q8oybjZelukF4h0CzSUN9', '4Y2glvLjQGOb4dXnwm1hQf', '722tgOgdIbNe3BEyLnejw4', '7ouMYWpwJ422jRcDASZB7P', '0WSa1sucoNRcEeULlZVQXj', '4KicwnxHDBQLfeytoUBmux', '1FBdX6uTlbunrv0bu3tFnF', '4ujbN7rTpEishNGPH00GfN', '4cluDES4hQEUhmXj6TXkSo']

# %% [markdown]
# # Spotify 플레이리스트에 담겨진 노래들 audio feature 추출할때

# %%
# Spotify API 인증 설정
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id="0f9a6c744c494cba948ec67949d9158c",       # Spotify에서 발급받은 Client ID
    client_secret="bdaffd4b3d514ee48aae9842ecffa0cf" # Spotify에서 발급받은 Client Secret
))

# 플레이리스트 ID를 통해 트랙 ID 가져오는 함수
def get_playlist_track_ids(playlist_id):
    results = sp.playlist_tracks(playlist_id)
    tracks = results['items']
    
    track_ids = []
    
    # 플레이리스트 내 모든 트랙의 ID를 track_ids 리스트에 추가
    for item in tracks:
        track = item['track']
        track_ids.append(track['id'])
    
    return track_ids

# 예시 플레이리스트 ID (이 부분을 실제로 제공받은 playlist_id로 대체하세요)
playlist_id = '3d7l2gmMWjDGMfKZCTawbS'  # 실제 playlist_id로 대체하세요

# 플레이리스트에 담긴 트랙 ID 가져오기
track_ids = get_playlist_track_ids(playlist_id)

# 결과 출력
print(track_ids)
# Out:
# ['0T3gqQBET5hnKf0ZZxoK0Y', '0HsRZwZzHoZ5AM5W2ZYI5c', '2kNBPsz22Ic5SXzFsS0ltQ', '2V7xL8Sz8uQgnkjduiJHQE', '65OSFoF3g8ACt8m44qrqJT', '1q4FmOZDVNqozyHHHF5Qef', '6qL7eEYcUUUBPi7xLr0gzZ', '2odm919sRfQIhH2na8YSKK', '2K5JDQK0eG2EWQAfa4gmoa', '5vYcSo3ZCEWTrjevlj8zL9', '7nirS2RArSJE0zVLG8rkpT', '4LxFRsy3TZjqAtAgIsjkez', '10qiH1RJkexhTUuN562FsP', '51kQvG4aghW17VSZKkfxTp', '7KRcAAVwN5K4nDiQAhkDxe', '231FbnNQRNo9PMwEyu8Tp9', '628SaXSeaB78ndGYwIvPeR', '4OHq2ao4pXmGq9OOuP3lxb', '0dGXcOzlAW8lAZA5fjqBrW', '3MTvntVAyy2JmRFilA5eWv', '75ai0ibymmqyCyaxwZuhnu', '5jdg9rY3ki7lCN3bu4BzsS', '7qU13A3cPvKc7SaVfQImMP', '0iFHvtq09QSvKF6btusqcD', '36PxJOUB8qFTcDFp2M0h6K', '4p4yxplNCSmt9xfaAMpcd5', '24ISyrkOgpc0IodIEUokog', '0XAjKGJBKFVfiG3XvGwIcH', '0wnSAKtD7n2Z5uOZcu0Obr', '34HSEUn4YGAFBW9OHGIkU7', '2VKiCkGBpM157WKAue0W23', '7gXMkqirKU23zgdlSAb00a', '4TlOsdI9nScXp9drxUOZVk', '4F4huaUlaZDkAHLvXXRWaU', '0ABgWfH4ksW7hZ7EQWN8Fh', '5BVRrg0ewd72Jdzj7Oizty', '6GJJ8nmShJUDSIyyjl9yqv', '4axFfUXAF9rJvDeaYrmD4m', '1WKfJn8wUuUXBSVJBEytq0', '7C7XtvAd8sjNtXRKzFMzBe', '0snab11W7ZrT1326HWrtR9', '1lcRKgU8mtBZTXq0sGUAzy', '1v4m9GLt7lpFM5iOvwQZrU', '23PyDwW8pLgDsjpyFdjYgj', '349TY23ZYSFWwVvHJR4HCG', '1ZEFYW6nPEvIcsIvymgsLk', '3AJwUDP919kvQ9QcozQPxg', '75JFxkI2RXiU7L9VXzMkle', '1HNkqx9Ahdgi1Ixy2xkKkL', '1jlC6MEmlRbjMV182flmYZ', '1x0XsQ5XY9g9iNvV3YZO35', '0WOvSEVpUGkNufX0w0M06F', '3ZScgtW6j4p2XI0RgfIaBk', '02ESexzRg6QHCR0Cs7DGSg', '3ryHmf5w5VlnE4QAe9lEIs', '6EWWZTKKhFh7sTYsm65zfV', '7ix35I3PNAN63JeV7feOG9', '2qrDQX9IvOhetvjUcwPtmb', '5xX7oEKHN0H9VOjezo2ZaA', '63qhb9Fa4A4aF5P30s0PhH']

# %% [markdown]
# # 위 2가지 방식 중 하나로 담겨진 노래 id들로부터 spotify api 사용해서 audio feature 추출하고 json 파일에 저장하기

# %%
# Spotify API 인증 설정
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id="0f9a6c744c494cba948ec67949d9158c",       # Spotify에서 발급받은 Client ID
    client_secret="bdaffd4b3d514ee48aae9842ecffa0cf" # Spotify에서 발급받은 Client Secret
))

# 필요한 오디오 피쳐를 가져오는 함수
def get_selected_audio_features(track_id):
    features = sp.audio_features(track_id)
    if features and features[0]:  # features[0]이 None이 아닌 경우
        audio_features = features[0]
        # 7가지 피쳐를 리스트 형태로 추출
        selected_features = [
            audio_features['tempo'],
            audio_features['valence'],
            audio_features['energy'],
            audio_features['danceability'],
            audio_features['acousticness'],
            audio_features['speechiness'],
            audio_features['liveness']
        ]
        return selected_features
    return None

# 트랙 ID를 통해 노래 제목 가져오기
def get_track_name(track_id):
    track_info = sp.track(track_id)
    if track_info:
        return track_info['name']
    return None

# 기존 JSON 파일을 읽어오는 함수
def load_audio_features_data(file_path):
    try:
        with open(file_path, 'r') as f:
            data = json.load(f)
    except FileNotFoundError:
        # 파일이 없는 경우 빈 딕셔너리 반환
        data = {}
    return data

# 업데이트된 데이터를 JSON 파일에 저장하는 함수
def save_audio_features_data(audio_features_data, file_path):
    try:
        with open(file_path, 'w') as f:
            json.dump(audio_features_data, f, indent=4)  # indent=4는 보기 좋게 들여쓰기
        print(f"데이터가 {file_path}에 성공적으로 저장되었습니다.")
    except Exception as e:
        print(f"파일을 저장하는 데 오류가 발생했습니다: {e}")

# 트랙 ID를 통해 오디오 피쳐를 추출하고 저장하는 함수
def process_tracks(track_ids, file_path):
    audio_features_data = load_audio_features_data(file_path)
    
    for track_id in track_ids:
        try:
            track_name = get_track_name(track_id)
            if not track_name:
                print(f"트랙 이름을 가져올 수 없습니다: {track_id}")
                continue
            
            selected_features = get_selected_audio_features(track_id)
            if selected_features:
                audio_features_data[track_name] = selected_features
                print(f"트랙 {track_name}의 오디오 피쳐가 업데이트되었습니다.")
                
                # 업데이트된 데이터 저장
                save_audio_features_data(audio_features_data, file_path)
            else:
                print(f"해당 트랙에 대한 오디오 피쳐를 가져올 수 없습니다: {track_name} ({track_id})")
        except Exception as e:
            print(f"오류 발생: {e} (트랙 ID: {track_id})")
        
# 파일 경로 설정 ** 레이블 잘확인하기 (절대 경로로 확인)
file_path = os.path.abspath('data/anger.json')
print(f"파일 경로 확인: {file_path}")


# 제공된 track_id를 통해 오디오 피쳐 분석 및 업데이트
process_tracks(track_ids, file_path)
# Out:
# 파일 경로 확인: c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json
# 트랙 Love The Way You Lie의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Blood On The Leaves의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 MELODY의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 돌덩이의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 FIRE (Prod. by GroovyRoom)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Firework의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Roar의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 The Hills의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Believer의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 DICE의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Paranoid의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Empire State Of Mind의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Don't Cry의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Beautiful Things의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Stronger (What Doesn't Kill You)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Lazenca, Save Us (우리 동네 음악대장) (Bonus Track)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Chandelier의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Hello의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 My Way의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 A Flying Butterfly의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 금지된 사랑의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 그때 그 아인의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Memory Of The Wind의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Memory Of The Wind의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 형의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Creep의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Take Me To Church의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Before You Go의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Happier Than Ever의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Outnumbered의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Midnight City의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Pompeii의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Demons의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Runaway의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Outro의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 A Moment Apart의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Time의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Hurt의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Elastic Heart의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 you should see me in a crown의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 In the End의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 It's Time의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Radioactive의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Smells Like Teen Spirit의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Clarity의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Scary Monsters and Nice Sprites의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Witchcraft의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Black Skinhead의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Knights of Cydonia의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Can You Feel My Heart의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Architect의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 CHRISTIAN의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Fire Flower (Feat. Jo Hyun Ah)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 What Makes You Beautiful의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\LG\Desktop\VScode\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
