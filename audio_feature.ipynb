# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import json
import os
import numpy as np

# %%
import pandas as pd

# 엑셀 파일 경로 설정 (경로를 절대 경로로 정확하게 설정해야 합니다)
excel_file_path = 'ANGRY_MUSIC.xlsx'  # 실제 엑셀 파일 이름으로 대체

# 엑셀 파일 읽기
df = pd.read_excel(excel_file_path)

# 'ID' 열에서 track_id 가져오기
track_ids = df['ANGER_MUSIC'].tolist()

# track_ids 확인
print(track_ids)
# Out:
# ['3ZOEytgrvLwQaqXreDs2Jx', '4OssqCixV2Xsxd43wMIQyS', '0UHxkkgI5GfV0XBRA1rqfe', '4SxtjfUfvCe4NoeDAY0YhF', '0dkqqQAizwp3MHJKehq5ng', '67awxiNHNyjMXhVgsHuIrs', '3H09JZQLeSzeYbbA1Ptoxx', '503OTo2dSqe7qk76rgsbep', '70JfqvAbQmdBs7Vp9nXtLT', '2RsLP2sl9rEUD03H7afuBZ', '4SI3VVjbgpdzAGeGHsUUYk', '2FY7b99s15jUprqC0M5NCT', '0VeoSHlgashtg5JYPJjl15', '5Ln8eNkYC9to99zsPEZbS2', '4QFsfUVgZesJCJ7jQXCXZ4', '7jwDuO7UZvWs77KNj9HbvF', '6hypt8VPJxeMXTTcRUHS86', '3TJVugjg8TmJi9EfVg2WHg', '0cDvhhOtksLw2vL7FyVHuG', '3ulX3obs7oJGzluQNzcIDX', '5Nlr3ZAz0J3N0IJSVeEe6g', '22FjLaQai9qtKtBFk9hezQ', '5bhhVjQRtMTvBUIqsYdd6M', '3TVPGk9hkCLnUP17yOAxAJ', '0YjaYbmmCgUUwOVAA3wqiV', '5UKf82epsMYtjpZR9QGtns', '4YgSIuuzYOpQnNIJzgnZky', '02z5dvVbZTECROudTrsiKr', '1jCRPdDQvCA5kQXtrPFWPC', '0tokbEw27FxVHubsv8ZYN4', '40f7kH91oiBssFZn0kYB3V', '6Y8BMJXyRWVpxzQt3WDEmb', '4aOOExMBUyxKnEYb39SrTg', '2HHtWyy5CgaQbC7XSoOb0e', '36AvhOlf9OqDAzlL0X3BKk', '4kTZPPL28sYltXKMJramko', '6pK3MdL00xhxIfhHDVfQaO', '3hVEpnbIFzZpUbSfCCAglQ', '5JjnoGJyOxfSZUZtk2rRwZ', '7apulxaJlvATGApGo61jIK', '7B7juUvkVza0u6lZV8uMPk', '6T3ujw0cQWTbukpCRYoPBJ', '71fA2O5U6qf90ekBMXDsDB', '57dAn3xBS8XfKeWJBmoTCC', '6yd5t2nC2Trq7XbtqaiLPU', '0eYPC664DKX8ztD4CRcTk9', '3BA0aMD6fZIjh9qyidd22B', '7a733QhzAN4jdckPKCbD82', '31CQgZwDOqW4TPWbLFQXm8', '1gzlX6R049lAZuJ9IEwqwc', '2wVLe3Ch8UbyzeapLMPwuq', '2UKARCqDrhkYDoVR4FN5Wi', '1XTGyfJeMiZXrZ1W3NolcB', '3By9jCy6b4dv5XnlhvIWwx', '2xJ9kcY65dxKtx81YOCa1K', '36jabPLz0Cz7ZblFAmi7sD', '5qZMqZspIglsy4SJxtJt0S', '6LSRHi9dycuaS83L0Yych1', '1cYDmIZtF2SGveyqhc7X1Y', '2qR0mMrgwO099ONpl2B0II', '722tgOgdIbNe3BEyLnejw4', '2C05PdbQkz79ue76TQ2uEv', '3vzKFyAsVtOhTxQe21mxk9', '044Zn9AfTAwACRqu15vvp5', '4LFBVDJV0xpayUvquQVzhS', '7C8nA84nqtzdTZdKq9YVGF', '1FvZeK3MgmGldxeYDvzanR', '5uraJqtCBvLpwt3VeomZdq', '6rsbsdiGDrYvhbb1K7ziTL']

# %%
# Spotify API 인증 설정
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id="0f9a6c744c494cba948ec67949d9158c",       # Spotify에서 발급받은 Client ID
    client_secret="bdaffd4b3d514ee48aae9842ecffa0cf" # Spotify에서 발급받은 Client Secret
))

# 플레이리스트 ID를 통해 트랙 ID 가져오는 함수
def get_playlist_track_ids(playlist_id):
    results = sp.playlist_tracks(playlist_id)
    tracks = results['items']
    
    track_ids = []
    
    # 플레이리스트 내 모든 트랙의 ID를 track_ids 리스트에 추가
    for item in tracks:
        track = item['track']
        track_ids.append(track['id'])
    
    return track_ids

# 예시 플레이리스트 ID (이 부분을 실제로 제공받은 playlist_id로 대체하세요)
playlist_id = '1stCq3IhxqoIu7xfaWPIAc'  # 실제 playlist_id로 대체하세요

# 플레이리스트에 담긴 트랙 ID 가져오기
track_ids = get_playlist_track_ids(playlist_id)

# 결과 출력
print(track_ids)
# Out:
# ['5TkU8dzEi3UcxyYntZWHzI', '6s5QnuRQq0ANOo1pkz7mJv', '11UlvFPYzGXfxtrGmPxb55', '02UNF1uo5f0UNgc1qx5XGt', '3aW0ds4A4tSQDIp75FqWTo', '55mjIth3WxnK3p42uyRBwN', '6bX31xvB4HeeUOMorR77oV', '7e7VjLxO5xJINHvnRytrqi', '5WO8MdgIrbNBo9TeKzTVBl', '7k5iu5vr7IEW3BdSgwY9mw', '2FsDBjidfX0j1uuhRhOIKX', '0a3Zd8Bjs8WvnrRfYQQVAL', '0jyFdJsPFkj7zzoXzW0vMD', '5Hkk4YCNakpuOpbZQo67fE', '5KawlOMHjWeUjQtnuRs22c', '6T3Mlx5fr71sm0u1YDAb4R', '2dYl2SI3sLyUffzxVBaZBz', '2HtcPHFdo7eu4Ilbvb0BVI', '1Zyd6zQnC6XIIzmg3hP7Ot', '3AQmPrSm6KOEYVhntoBdFX', '30H0FtOCtb5jESDvFcxqXZ', '14k6gKt31iYXzUrsF8fyXH', '2zlgwqw8BLX2JGB76LIFeF', '5gkB40BDQE1CvtXpF6fcPm', '4r5d7zEBmDBFxKv5JfjSaY', '0QIRm9sUkGnezGznkWCqCo', '0q3xk0VI0w7omVXYA09sVw', '3PWyoYwI4iHLnLWltMt4gd', '4F9EZD74cDuCwqn3neLqJE', '5NnNl71fwVkuB1M45CXvdb', '4a1FFgdBIbAvyn4d40YAPZ', '3CV5ak1oN85Vjx1NHiLK7H', '6vs7hcMDl4l6BQKL9KE9pd', '6BcOOZoCGPaUuEPGNqGQx2', '5A0ut5JjeNLgGaScBIRyBU', '3IZQ0nbBU9tIJxQxHwB5LS', '59FBFyeST1vqN8G41YgFS6', '7ppOWC1tLH7dryAau647oQ', '6BKOhvRPY54uvfqWwg7MKi', '7pm5uhK7xiEM9fQvuCE78l', '2ZMzg8vFYRbvVZvzqx3jMT', '09CAOGrMHucCFL64TYGJ7H', '4O4bVvgUrB4IYvZsvIm8hA', '5ktwBE88NKZSfmk6Lw2KhS', '6Rx0ORYPP3GH9rTvGS5Vy8', '1DHkVkpOeNXxq4YhHOeEac', '62FiiEvPsllw9G9NQkVEdK', '0ZOF1KJvyzyZj6RrQ0fK2t', '42reErFmOTjPS2x8tbSw5N', '6W4G44h5B23jv5E2S0NUkw', '7Hjmz2XTMCuFvKBSfvrtC5', '0AdhtjSuzcZQIwWD0n57sZ', '6qAzAmPBUpGrk7XADZHR5k', '0kqvpNd0TCX8fmHWA6QljD', '3VTvrr2jER0dZfHn7GB0vu', '4c1cUu1PFDX1YB6JDvG8vf', '68daw5D7jgDf55BJmaiQIf', '7y9FSrF6PBzTWwQIOVVUOj', '6x7fux7bZEfnChKx3nhSZn', '5ZkITfPpcNPnyYGTibkO6m', '4eiPbjcTEJDQcsv7WV0vfD', '6jjd5vJtgKwzMtxJeTlLqH', '3ELLtSclCBRIJKhiTRF7Y8', '4Svdl1Y1bjR9A6AtugiyBM', '0GsRx0gPft6RmijIwMsKmG', '5QhE3ILw6KUR40fe0w35bb', '64hbVhrotZmYtuB86s89y9', '4sa8O4AwMja6r1Enu35Fmz', '29j6CUHUqJg1uJCsAvcBQP', '1kFevEv3s7Gf6o5xSDR5DL', '7EZ79Zl4XsPS320q0KXC6E', '5Y9mRAtmRh1VgFepfJfCTY', '6qbIDrT2mRdr7kZiOtHnIe', '3KoaLjT5xDEeP16ipfBAW4', '1YqGY2dW0a9ocyxaB5PtrR', '46FYaf7nSEeGilX2ETHfgl', '3eHkFA3StDR9BU7EVrUFLs', '0rDW8yZoFLfXuSISsFhkGK', '4HZtdVxrS8AboDfySCApWd', '405SQUJdQut02dxtuQ0CZ3', '2e460Sd7WZ6BQTNuzK3FwE', '0cd3t9ifOeJVirxWxcUNsJ', '5hpeThtSukQ7R00YS8AKK8', '5raBru10U4qA2zexhixC4D', '5wJJvq3kOukktCgYjwAOfX', '0yD2ihr9ZseEZQXQcz6y61', '67bVDuhVNpGahHOJGsv8BQ']

# %%
# Spotify API 인증 설정
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id="0f9a6c744c494cba948ec67949d9158c",       # Spotify에서 발급받은 Client ID
    client_secret="bdaffd4b3d514ee48aae9842ecffa0cf" # Spotify에서 발급받은 Client Secret
))

# 필요한 오디오 피쳐를 가져오는 함수
def get_selected_audio_features(track_id):
    features = sp.audio_features(track_id)
    if features and features[0]:  # features[0]이 None이 아닌 경우
        audio_features = features[0]
        # 7가지 피쳐를 리스트 형태로 추출
        selected_features = [
            audio_features['tempo'],
            audio_features['valence'],
            audio_features['energy'],
            audio_features['danceability'],
            audio_features['acousticness'],
            audio_features['speechiness'],
            audio_features['liveness']
        ]
        return selected_features
    return None

# 트랙 ID를 통해 노래 제목 가져오기
def get_track_name(track_id):
    track_info = sp.track(track_id)
    if track_info:
        return track_info['name']
    return None

# 기존 JSON 파일을 읽어오는 함수
def load_audio_features_data(file_path):
    try:
        with open(file_path, 'r') as f:
            data = json.load(f)
    except FileNotFoundError:
        # 파일이 없는 경우 빈 딕셔너리 반환
        data = {}
    return data

# 업데이트된 데이터를 JSON 파일에 저장하는 함수
def save_audio_features_data(audio_features_data, file_path):
    try:
        with open(file_path, 'w') as f:
            json.dump(audio_features_data, f, indent=4)  # indent=4는 보기 좋게 들여쓰기
        print(f"데이터가 {file_path}에 성공적으로 저장되었습니다.")
    except Exception as e:
        print(f"파일을 저장하는 데 오류가 발생했습니다: {e}")

# 트랙 ID를 통해 오디오 피쳐를 추출하고 저장하는 함수
def process_tracks(track_ids, file_path):
    audio_features_data = load_audio_features_data(file_path)
    
    for track_id in track_ids:
        try:
            track_name = get_track_name(track_id)
            if not track_name:
                print(f"트랙 이름을 가져올 수 없습니다: {track_id}")
                continue
            
            selected_features = get_selected_audio_features(track_id)
            if selected_features:
                audio_features_data[track_name] = selected_features
                print(f"트랙 {track_name}의 오디오 피쳐가 업데이트되었습니다.")
                
                # 업데이트된 데이터 저장
                save_audio_features_data(audio_features_data, file_path)
            else:
                print(f"해당 트랙에 대한 오디오 피쳐를 가져올 수 없습니다: {track_name} ({track_id})")
        except Exception as e:
            print(f"오류 발생: {e} (트랙 ID: {track_id})")
        
# 파일 경로 설정 (절대 경로로 확인)
file_path = os.path.abspath('audio_features_data.json')
print(f"파일 경로 확인: {file_path}")


# 제공된 track_id를 통해 오디오 피쳐 분석 및 업데이트
process_tracks(track_ids, file_path)
# Out:
# 파일 경로 확인: c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json
# 트랙 First Love의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 내가 저지른 사랑의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Ugly의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 REALLY REALLY의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 FAKE LOVE의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 My Destiny의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 죽어도 못 보내의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 PLAYING WITH FIRE의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 눈물 (Feat. 유진 Of 더 씨야)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Memory Of The Wind의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Living in the Same Time의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Cherry Blossom Ending의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Yeosu Night Sea의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Wild Flower의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Boy With Luv (feat. Halsey)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Galaxy 우주를 줄게의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Knock Knock의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Feel Special의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 As If It's Your Last의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 어디에도 No metter where의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Making a new ending for this story의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Fear의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Missing You의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 봄이 좋냐?? What The Spring??의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Don't Be Shy의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 BANG BANG BANG의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Eat의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 No Make Up의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Shouldn't Have...의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Wi Ing Wi Ing 위잉위잉의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 LOSER의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 BAE BAE의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Just (From Young)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Yanghwa BRDG의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Spring Is Gone by chance의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Love Again의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 SHAKE IT의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Comes and Goes 와리가리의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Up & Down의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Heart Attack의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Puss의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Only You의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Two Lovers의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 heart의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 CALL ME BABY의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Me You (feat. Baek Yerin)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Because of you의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 목소리의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Um Oh Ah Yeh의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Only You의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Who's Your Mama?의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Snow Of April의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 LOVE SCENARIO의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 MY TYPE의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Wild Flower의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 L.I.E의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Ah Yeah의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Fire (feat.Jinsil Of Mad Soul Child)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Me Gustas Tu의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 I의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Why의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 IF YOU의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 GET SOME AIR (feat.MIWOO)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Geobukseon의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Friday (feat.Jang Yi-jeong)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Let's not fall in love의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 OPPA CAR의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Oasis의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Cry Again의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 LOVE ME RIGHT의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 LUV의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 just looking 바라보기의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Greatest Time (feat.HuhGak)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Love mash (feat.Chancellor of the channels)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 광화문에서 (At Gwanghwamun)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 My Type의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 WINE (Feat.Changmo) (Prod. SUGA)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 SOBER의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 WE LIKE 2 PARTY의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Lion Heart의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 사랑에 빠지고 싶다의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Lean On Me의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Evening sky의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Heaven의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Be the Light의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Toy의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 You and I (Park Bom)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
