# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import json
import os
import numpy as np
import openpyxl

# %% [markdown]
# # 엑셀 파일로 노래라벨링된거에서 audio feature 추출할때

# %%
import pandas as pd

# anger, disgust, fear, joy, neutral, sadness, surprise
# 엑셀 파일 경로 설정 (경로를 절대 경로로 정확하게 설정해야 합니다)
excel_file_path = 'C:/Users/LG/Desktop/VScode/gg-project/excel_file/surprise.xlsx'  
# 실제 엑셀 파일 이름으로 대체

# 엑셀 파일 읽기
df = pd.read_excel(excel_file_path)

# 'ID' 열에서 track_id 가져오기
track_ids = df['id'].tolist()

# track_ids 확인
print(track_ids)
# Out:
# ['15JINEqzVMv3SvJTAXAKED', '42GcjriRK6srwHkfbkBqVl', '259wZqRoiqkrRMosDDnnOX', '1jCRPdDQvCA5kQXtrPFWPC', '44qSm80CrnBt3Mry9vYE41', '1mXuMM6zjPgjL4asbBsgnt', '6F5c58TMEs1byxUstkzVeM', '7fBv7CLKzipRk6EC6TWHOB', '0pqnGHJpmpxLKifKRmU6WP', '6C734SmqoIYuRWo2qSCnpC', '4f3E2bdBCYDvC0otoYcdXg', '2igwFfvr1OAGX9SKDCPBwO', '2SVhXAyqWACGVzVv8jWeRf', '6tNQ70jh4OwmPGpYy6R2o9', '1nInOsHbtotAmEOQhtvnzP', '0tokbEw27FxVHubsv8ZYN4', '4VrWlk8IQxevMvERoX08iC', '1Yk0cQdMLx5RzzFTYwmuld', '4fOfwLHQJz49Q8T1jrz54I', '3I71PFicYG614VGl6hqcUK', '0JtYYcQ330UyNftbi1tM0H', '7mCdQsRW5gLLxVGDPPGt5j', '1uMLtqpe8beA6fPy3ApJcJ', '1uMLtqpe8beA6fPy3ApJcJ', '63jOB9nkgSTrmwTvmfO3DE', '70LcF31zb1H0PyJoS1Sx1r', '3dYD57lRAUcMHufyqn9GcI', '2gMXnyrvIjhVBUZwvLZDMP', '4RVwu0g32PAqgUiJoXsdF8', '6UjZ2Yx2g2a52XxiA8ONxZ', '6GyFP1nfCDB8lbD2bG0Hq9', '6fNhZRFEkBfgW39W3wKARJ', '5VC29kHMkzcaorzPKUqJbl', '3DK6m7It6Pw857FcQftMds', '1s9i7W8zx7Nxx78MUIsvjV', '59wlTaYOL5tDUgXnbBQ3my', '6ZFbXIJkuI1dVNWvzJzown', '6gDXbcILAyBa2skSdbUYq7', '6kwAbEjseqBob48jCus7Sz', '3XF5xLJHOQQRbWya6hBp7d', '60a0Rd6pjrkxjPbaKzXjfq', '7MXlTgQeo3IVlMpLnZuhxc', '62yJjFtgkhUrXktIoSjgP2', '4CeeEOM32jQcH3eN9Q2dGj', '60wwxj6Dd9NJlirf84wr2c', '5q8oybjZelukF4h0CzSUN9', '4Y2glvLjQGOb4dXnwm1hQf', '722tgOgdIbNe3BEyLnejw4', '7ouMYWpwJ422jRcDASZB7P', '0WSa1sucoNRcEeULlZVQXj', '4KicwnxHDBQLfeytoUBmux', '1FBdX6uTlbunrv0bu3tFnF', '4ujbN7rTpEishNGPH00GfN', '4cluDES4hQEUhmXj6TXkSo']

# %% [markdown]
# # Spotify 플레이리스트에 담겨진 노래들 audio feature 추출할때

# %%
# Spotify API 인증 설정
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id="0f9a6c744c494cba948ec67949d9158c",       # Spotify에서 발급받은 Client ID
    client_secret="bdaffd4b3d514ee48aae9842ecffa0cf" # Spotify에서 발급받은 Client Secret
))

# 플레이리스트 ID를 통해 트랙 ID 가져오는 함수
def get_playlist_track_ids(playlist_id):
    results = sp.playlist_tracks(playlist_id)
    tracks = results['items']
    
    track_ids = []
    
    # 플레이리스트 내 모든 트랙의 ID를 track_ids 리스트에 추가
    for item in tracks:
        track = item['track']
        track_ids.append(track['id'])
    
    return track_ids

# 예시 플레이리스트 ID (이 부분을 실제로 제공받은 playlist_id로 대체하세요)
playlist_id = '37i9dQZF1DZ06evO2kmZIk'  # 실제 playlist_id로 대체하세요

# 플레이리스트에 담긴 트랙 ID 가져오기
track_ids = get_playlist_track_ids(playlist_id)

# 결과 출력
print(track_ids)
# Out:
# ['3xDYVkGV8EDDRwzyDH1a6p', '20e0EjOZrM0AEMSepdh2fU', '7KLKXIfYCvAC6BOGXRUDNi', '5R2trFl2sS9RPloez91GVB', '0awns037OT5FraMYo8jpUD', '1YXYleLFyTRQMMitfL2mdL', '5c7WrxQsEzSOr4udppQCHx', '61pIVBFhsQROJcQqzyZfXR', '3vDSycAcp3rd3iL4uUfX56', '0NXN8CNyQOQvZuSuFP75IB', '6EU4Ox9nBAE4BMatsggp8i', '2Zlh1aW0hk1nltiglaCzfi', '5zat3M63anEh7vaCRGIco6', '5UKf82epsMYtjpZR9QGtns', '5CDTCUl3TD36C5Ezhdfr3C', '07jOogwG0xr8UjtsxqdhPH', '6YeSeGAD6bVLsGIswaeWTt', '2BYPXuBxb7cY9FGxsgDSmv', '4an1bGdcwBt5yDAsA6q7aM', '3HDTmeDUjMFpWjIpicAbTC', '2MDyIYGyysalcAUI6hObMn', '24H85lQQGb9SrjM1RRyGJx', '6BlEAqSPJJlae5v7d8Dqqc', '2eQEBStK2KPBtnCSXbsPid', '7xGcU76wD4qwewSu9vi13e', '4YgSIuuzYOpQnNIJzgnZky', '0wa6QQYA9Y64ORUXRlvj73', '0EwJhOUYsBfRhtq5DiB2DR', '0sDgKU5TE3m3uaZztiesi3', '78U5EQ7HS8i9ie2f802gzQ', '3huX6IPP80pZmLAgiDtiqy', '1yHWtHigp5Pryd3e9QvxVl', '457fxClHtZwPBZlWcR0XJL', '3G19fRmHAbmoQyUOQGu55h', '6tFvVUgKl29I8vVfCN9vWC', '0LzTkTN0u6xo011l8dafHi', '15dd4M9GAV1RhEH0qesnKL', '46kHdS6WqLTal5po1gJZbL', '5cGJjMhvFfx7UxZuWVOZ6M', '2zGm9tbkCwIXMGsseDOhhr', '3o7GWQoDBexBtRZNHWDR8X', '6Ys5ANZ0vqdnD9apUTSqi1', '6tFRltu0UeOmVm6ebmeUtJ', '20qJC34w7dz7lzqlgCA41r', '2tV1AAwXbw5kJfT4pK70Dg', '6OkseHBCi3Cf53nsi45ffK', '5Ec1siRgUvcVAiHkbF2Ftx', '1dAkkWCdecpqI63vHsRaUL', '3bdP3Vn6YSlNWiqf1G8fxt', '06XLXdU1hcdGb98PvAMk0Z']

# %% [markdown]
# # 위 2가지 방식 중 하나로 담겨진 노래 id들로부터 spotify api 사용해서 audio feature 추출하고 json 파일에 저장하기

# %%
# Spotify API 인증 설정
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id="0f9a6c744c494cba948ec67949d9158c",       # Spotify에서 발급받은 Client ID
    client_secret="bdaffd4b3d514ee48aae9842ecffa0cf" # Spotify에서 발급받은 Client Secret
))

# 필요한 오디오 피쳐를 가져오는 함수
def get_selected_audio_features(track_id):
    features = sp.audio_features(track_id)
    if features and features[0]:  # features[0]이 None이 아닌 경우
        audio_features = features[0]
        # 7가지 피쳐를 리스트 형태로 추출
        selected_features = [
            audio_features['tempo'],
            audio_features['valence'],
            audio_features['energy'],
            audio_features['danceability'],
            audio_features['acousticness'],
            audio_features['speechiness'],
            audio_features['liveness']
        ]
        return selected_features
    return None

# 트랙 ID를 통해 노래 제목 가져오기
def get_track_name(track_id):
    track_info = sp.track(track_id)
    if track_info:
        return track_info['name']
    return None

# 기존 JSON 파일을 읽어오는 함수
def load_audio_features_data(file_path):
    try:
        with open(file_path, 'r') as f:
            data = json.load(f)
    except FileNotFoundError:
        # 파일이 없는 경우 빈 딕셔너리 반환
        data = {}
    return data

# 업데이트된 데이터를 JSON 파일에 저장하는 함수
def save_audio_features_data(audio_features_data, file_path):
    try:
        with open(file_path, 'w') as f:
            json.dump(audio_features_data, f, indent=4)  # indent=4는 보기 좋게 들여쓰기
        print(f"데이터가 {file_path}에 성공적으로 저장되었습니다.")
    except Exception as e:
        print(f"파일을 저장하는 데 오류가 발생했습니다: {e}")

# 트랙 ID를 통해 오디오 피쳐를 추출하고 저장하는 함수
def process_tracks(track_ids, file_path):
    audio_features_data = load_audio_features_data(file_path)
    
    for track_id in track_ids:
        try:
            track_name = get_track_name(track_id)
            if not track_name:
                print(f"트랙 이름을 가져올 수 없습니다: {track_id}")
                continue
            
            selected_features = get_selected_audio_features(track_id)
            if selected_features:
                audio_features_data[track_name] = selected_features
                print(f"트랙 {track_name}의 오디오 피쳐가 업데이트되었습니다.")
                
                # 업데이트된 데이터 저장
                save_audio_features_data(audio_features_data, file_path)
            else:
                print(f"해당 트랙에 대한 오디오 피쳐를 가져올 수 없습니다: {track_name} ({track_id})")
        except Exception as e:
            print(f"오류 발생: {e} (트랙 ID: {track_id})")
        
# 파일 경로 설정 (절대 경로로 확인)
file_path = os.path.abspath('audio_features_data.json')
print(f"파일 경로 확인: {file_path}")


# 제공된 track_id를 통해 오디오 피쳐 분석 및 업데이트
process_tracks(track_ids, file_path)
# Out:
# 파일 경로 확인: c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json
# 트랙 Dark Clouds의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 love me (feat. Hoody)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Babo (feat. nafla) - Acoustic Version의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Nae Tat의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Wu의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 merlot의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Señorita (feat. nafla)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Put it on ya (Feat. BM of KARD, nafla)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 끌리는 대로 I’m good의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 ice coffee의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 under the ground (feat. Dean)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 NBA의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 119의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 run! (feat. JUSTHIS)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 gucci girl의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 No Tomorrow (Feat. lIlBOI, nafla)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 SUZURAN의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 i'm in love의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 I'm the ONE의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Take Me (feat. nafla)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 been의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 bite의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Buckle (Prod. by GIRIBOY)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 soft의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Umbrella Calls for Rain의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 jail의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Saturday의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 burn의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 115 (feat. pH-1)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Sunbbang (Prod. by GIRIBOY)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Career High (Feat. Paloalto, nafla, Chancellor)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 someday (feat. Gaeko & Yuza)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 mobb tang의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Atlantis의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 B.I.G.의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 show off (feat. BIBI)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 dreamin'의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Sunny Day (Feat. nafla)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Locked And Loaded (feat. Owen Ovadoz)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Ice King의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 today also (feat. Paloalto & The Quiett)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 takeover의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 smile의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 I’m Hooked의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 YNF (feat. nafla, Verbal Jint)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Keep Going (Feat. BewhY, nafla, ZICO) (Prod. By IOAH)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 Apple Box(feat. Loopy)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 LAND (Feat. nafla)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 mmm (feat. nafla)의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
# 트랙 FLEX의 오디오 피쳐가 업데이트되었습니다.
# 데이터가 c:\Users\user\대학\VScode_File\gg-project\audio_features_data.json에 성공적으로 저장되었습니다.
